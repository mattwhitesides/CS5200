# %%
import sys

# %%
txt_data = [line.rstrip('\n').rstrip(')').lstrip('(') for line in open('GraphData.txt')]
graph_data = []
graph_dict = {}
graph_dict_rev = {}

# Put graph data into a array of tuples.
for line in txt_data:
    split = line.split(',')
    if len(split) == 2:
        x = int(split[0])
        y = int(split[1])
        graph_data.append((x, y, abs(x - y)))

# %%
import sys
  
class Graph(): 
    def __init__(self, graph_data):         
        self.graph_data = graph_data
        
        self.graph_dict = {}
        self.graph_dict_rev = {}                
        self.build_graph_dict()
        
        self.V = len(self.graph_dict)
        
        self.graph = [[(0, 0) for i in range(self.V)] for j in range(self.V)]
        self.build_adj_list()
        
        self.cc = self.connectedComponents()
        
    def build_graph_dict(self):
        i = 0        
        for x in self.graph_data:
            if x[0] not in self.graph_dict:
                self.graph_dict[x[0]] = i
                self.graph_dict_rev[i] = x[0]
                i += 1
            if x[1] not in self.graph_dict:
                self.graph_dict[x[1]] = i
                self.graph_dict_rev[i] = x[1]
                i += 1     
        
    def build_adj_list(self):
        for d in self.graph_data:
            x = self.graph_dict[d[0]]
            y = self.graph_dict[d[1]]
            self.graph[x][y] = (y, d[2])
            self.graph[y][x] = (x, d[2])
            
    def print_cc_list(self):
        for c in cc:
            s = "["
            for x in c:
                s += str(self.graph_dict_rev[x]) + ','
            s = s[:-1]
            s += "]"
            print(s)        
            
    def printMST(self, parent): 
        print("Edge \tWeight")
        for i in range(1, self.V): 
            print(parent[i], "-", i, "\t", self.graph[i][ parent[i] ])

    def minKey(self, key, mstSet): 
        min = sys.maxsize 

        for v in range(self.V): 
            print(key[v], min, mstSet[v])
            if key[v] < min and mstSet[v] == False: 
                min = key[v] 
                min_index = v 

        return min_index 
    
    def DFSUtil(self, temp, v, visited): 
        # Mark the current vertex as visited 
        visited[v] = True

        # Store the vertex to list 
        temp.append(v) 
        

        # Repeat for all vertices adjacent 
        # to this vertex v 
        for i in self.graph[v]: 
            if visited[i[0]] == False: 

                # Update the list 
                temp = self.DFSUtil(temp, i[0], visited) 
        return temp 

    # Method to retrieve connected components 
    # in an undirected graph 
    def connectedComponents(self): 
        visited = [] 
        cc = [] 
        for i in range(self.V): 
            visited.append(False) 
        for v in range(self.V): 
            if visited[v] == False: 
                temp = [] 
                cc.append(self.DFSUtil(temp, v, visited)) 
        return cc     

    def primMST(self): 
        key = [sys.maxsize] * self.V 
        parent = [None] * self.V

        key[0] = 0 
        mstSet = [False] * self.V 
        parent[0] = -1

        for x in range(self.V): 
            u = self.minKey(key, mstSet) 
            mstSet[u] = True
            for v in range(self.V): 
                if self.graph[u][v] > 0 and mstSet[v] == False and key[v] > self.graph[u][v]: 
                        key[v] = self.graph[u][v] 
                        parent[v] = u 

        self.printMST(parent)

# %%
g = Graph(graph_data) 
cc = g.connectedComponents()

g.print_cc_list()

#print(g.graph)
# Out:
# [277,325,274,11,31,264,210,84,8,60,250,322,239,5,329,1,99,119,70,120,308,122,272,111,115,142,283,254,154,153,314,156,21,129,14,147,164,315,166,256,215,183,219,139,259,218,23,80,209,318,202,74,211,319,30,298,27,172,98,72,39,299,34,186,178,133,285,198,19,288,327,287,297,17,199,317,238,321,225,212,290,200,160,258,65,301,293,217,294,228,286,85,304,86,326,222,320,257,59,266,152,313,151,87,136,311,96,41,144,79,303,88,18,252,323,251,234,192,102,306,109,163,56,112,300,305,179,316,193,284,130,62,167,45,276,75,302,73,289,295,328,124,309,123,128,310,312,237,324,43,185,206,114,104,307,296,15,7,278]
# ...
